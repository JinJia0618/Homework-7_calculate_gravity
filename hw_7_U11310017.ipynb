# %%
import numpy as np

# %%
Gt=Ge*(1+0.00578895*np.sin(lat*fac)**2+0.000023462*np.sin(lat*fac)**4)

# %%
print(f"theorectical gravity:{Gt}")
# Out:
# theorectical gravity:981177.4397522432

# %%
print(np.sin(0))
# Out:
# 0.0

# %%
np.pi
# Out:
# 3.141592653589793

# %%
fac =np.pi/180.0

# %%
lon=12.1878;lat=48.1195;ele=487.9;Go=980717.39;Ge=978031.85
